# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"c:\Users\user\Desktop\Kaggle Datasets\swiggy.csv")

# %%
df.head()
# Out:
#        id               name    city rating     rating_count   cost  \
# 0  567335     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  531342  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  158203  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3  187912          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4  543530      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine          lic_no  \
# 0            Beverages,Pizzas  22122652000138
# 1               Sweets,Bakery  12117201000112
# 2                   Beverages  22121652000190
# 3            Fast Food,Indian  22119652000167
# 4  Italian-American,Fast Food  12122201000053
#
#                                                 link  \
# 0  https://www.swiggy.com/restaurants/ab-foods-po...
# 1  https://www.swiggy.com/restaurants/janta-sweet...
# 2  https://www.swiggy.com/restaurants/theka-coffe...
# 3  https://www.swiggy.com/restaurants/singh-hut-n...
# ...

# %%
df.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['id', 'name', 'city', 'rating', 'rating_count', 'cost', 'cuisine',
#        'lic_no', 'link', 'address', 'menu'],
#       dtype='object')>

# %%
df=df.drop(columns=["id","lic_no","link","menu","address"])

# %%
df
# Out:
#                             name      city rating     rating_count   cost  \
# 0                 AB FOODS POINT    Abohar     --  Too Few Ratings  ₹ 200
# 1              Janta Sweet House    Abohar    4.4      50+ ratings  ₹ 200
# 2              theka coffee desi    Abohar    3.8     100+ ratings  ₹ 100
# 3                      Singh Hut    Abohar    3.7      20+ ratings  ₹ 250
# 4                  GRILL MASTERS    Abohar     --  Too Few Ratings  ₹ 250
# ...                          ...       ...    ...              ...    ...
# 148536          The Food Delight  Yavatmal     --  Too Few Ratings  ₹ 200
# 148537  MAITRI FOODS & BEVERAGES  Yavatmal     --  Too Few Ratings  ₹ 300
# 148538           Cafe Bella Ciao  Yavatmal     --  Too Few Ratings  ₹ 300
# 148539               GRILL ZILLA  Yavatmal     --  Too Few Ratings  ₹ 250
# 148540            Lazeez kitchen  Yavatmal     --  Too Few Ratings  ₹ 200
#
#                            cuisine
# 0                 Beverages,Pizzas
# ...

# %%
df.columns
# Out:
# Index(['name', 'city', 'rating', 'rating_count', 'cost', 'cuisine'], dtype='object')

# %%
df.head()
# Out:
#                 name    city rating     rating_count   cost  \
# 0     AB FOODS POINT  Abohar     --  Too Few Ratings  ₹ 200
# 1  Janta Sweet House  Abohar    4.4      50+ ratings  ₹ 200
# 2  theka coffee desi  Abohar    3.8     100+ ratings  ₹ 100
# 3          Singh Hut  Abohar    3.7      20+ ratings  ₹ 250
# 4      GRILL MASTERS  Abohar     --  Too Few Ratings  ₹ 250
#
#                       cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food

# %%
df.isna().sum()
# Out:
# name             86
# city              0
# rating           86
# rating_count     86
# cost            131
# cuisine          99
# dtype: int64

# %%
df['cost']=df["cost"].str.strip("₹")

# %%
df.shape
# Out:
# (148541, 6)

# %%
df=df.dropna()

# %%
df.isna().sum()
df.duplicated().sum()
# Out:
# np.int64(10)

# %%
df.head()
# Out:
#                 name    city rating     rating_count  cost  \
# 0     AB FOODS POINT  Abohar     --  Too Few Ratings   200
# 1  Janta Sweet House  Abohar    4.4      50+ ratings   200
# 2  theka coffee desi  Abohar    3.8     100+ ratings   100
# 3          Singh Hut  Abohar    3.7      20+ ratings   250
# 4      GRILL MASTERS  Abohar     --  Too Few Ratings   250
#
#                       cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food

# %%
df["cost"]=df["cost"].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148398 entries, 0 to 148540
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          148398 non-null  object
#  1   city          148398 non-null  object
#  2   rating        148398 non-null  object
#  3   rating_count  148398 non-null  object
#  4   cost          148398 non-null  int64
#  5   cuisine       148398 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 7.9+ MB

# %%
import numpy as np

df['rating'] = df['rating'].replace('--', np.nan)

# %%
df["rating"]=df["rating"].astype("float")

# %%
df.isna().sum()
# Out:
# name                0
# city                0
# rating          86977
# rating_count        0
# cost                0
# cuisine             0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Loop through numeric columns
for col in df.select_dtypes(include="number").columns:
    plt.figure(figsize=(12,6))
    sns.histplot(df[col], kde=True, bins=30)  # bins for better granularity
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in df.select_dtypes(include="number").columns:
    plt.figure(figsize=(12,6))
    sns.boxplot(df[col])  # bins for better granularity
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
df['rating'] = df['rating'].fillna(df['rating'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148398 entries, 0 to 148540
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   name          148398 non-null  object
#  1   city          148398 non-null  object
#  2   rating        148398 non-null  float64
#  3   rating_count  148398 non-null  object
#  4   cost          148398 non-null  int64
#  5   cuisine       148398 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.9+ MB

# %%
df.describe()
# Out:
#               rating           cost
# count  148398.000000  148398.000000
# mean        3.956355     287.605237
# std         0.300478     796.762559
# min         1.000000       1.000000
# 25%         4.000000     200.000000
# 50%         4.000000     250.000000
# 75%         4.000000     300.000000
# max         5.000000  300350.000000

# %%
df.head()
# Out:
#                 name    city  rating     rating_count  cost  \
# 0     AB FOODS POINT  Abohar     4.0  Too Few Ratings   200
# 1  Janta Sweet House  Abohar     4.4      50+ ratings   200
# 2  theka coffee desi  Abohar     3.8     100+ ratings   100
# 3          Singh Hut  Abohar     3.7      20+ ratings   250
# 4      GRILL MASTERS  Abohar     4.0  Too Few Ratings   250
#
#                       cuisine
# 0            Beverages,Pizzas
# 1               Sweets,Bakery
# 2                   Beverages
# 3            Fast Food,Indian
# 4  Italian-American,Fast Food
