# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv(r"c:\Users\user\Desktop\Kaggle Datasets\student_depression_dataset.csv")

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %% [markdown]
# ## Data Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
#  10  Sleep Duration                         27901 non-null  object
#  11  Dietary Habits                         27901 non-null  object
#  12  Degree                                 27901 non-null  object
#  13  Have you ever had suicidal thoughts ?  27901 non-null  object
#  14  Work/Study Hours                       27901 non-null  float64
#  15  Financial Stress                       27901 non-null  object
#  16  Family History of Mental Illness       27901 non-null  object
#  17  Depression                             27901 non-null  int64
# dtypes: float64(7), int64(2), object(9)
# memory usage: 3.8+ MB

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %% [markdown]
# ## Changning Data Type

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#         Sleep Duration Dietary Habits   Degree  \
# 0          '5-6 hours'        Healthy  B.Pharm
# 1          '5-6 hours'       Moderate      BSc
# 2  'Less than 5 hours'        Healthy       BA
# 3          '7-8 hours'       Moderate      BCA
# 4          '5-6 hours'       Moderate   M.Tech
#
#   Have you ever had suicidal thoughts ?  Work/Study Hours Financial Stress  \
# 0                                   Yes               3.0              1.0
# 1                                    No               3.0              2.0
# 2                                    No               9.0              1.0
# 3                                   Yes               4.0              5.0
# 4                                   Yes               1.0              1.0
#
#   Family History of Mental Illness  Depression
# 0                               No           1
# 1                              Yes           0
# 2                              Yes           0
# 3                              Yes           1
# 4                               No           0

# %%
# Check the unique values and dtype of the "Financial Stress" column before conversion
financial_stress_info = {
    "dtype_before": df["Financial Stress"].dtype,
    "unique_values": df["Financial Stress"].unique(),
    "nan_count": df["Financial Stress"].isna().sum()
}

financial_stress_info
# Out:
# {'dtype_before': dtype('O'),
#  'unique_values': array(['1.0', '2.0', '5.0', '3.0', '4.0', '?'], dtype=object),
#  'nan_count': np.int64(0)}

# %%
# Step 1: Remove rows where 'Financial Stress' is '?'
df = df[df["Financial Stress"] != "?"].copy()

# Step 2: Convert the column to float, then to int
df["Financial Stress"] = df["Financial Stress"].astype(float).astype(int)

# Optional: Reset index
df.reset_index(drop=True, inplace=True)

# %%
df["Age"]=df["Age"].astype(int)
df["Academic Pressure"]=df["Academic Pressure"].astype(int)
df["Study Satisfaction"]=df["Study Satisfaction"].astype(int)
df["Work/Study Hours"]=df["Work/Study Hours"].astype(int)
df["Work Pressure"]=df["Work Pressure"].astype(int)

# %% [markdown]
# ## Data Cleaning and Removing Column For Better Readability

# %%
df.drop(columns=["id"],inplace=True)

# %%
df.isna().sum()
# Out:
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Gender  Age           City Profession  Academic Pressure  Work Pressure  \
# 0    Male   33  Visakhapatnam    Student                  5              0
# 1  Female   24      Bangalore    Student                  2              0
# 2    Male   31       Srinagar    Student                  3              0
# 3  Female   28       Varanasi    Student                  3              0
# 4  Female   25         Jaipur    Student                  4              0
#
#    CGPA  Study Satisfaction  Job Satisfaction       Sleep Duration  \
# 0  8.97                   2               0.0          '5-6 hours'
# 1  5.90                   5               0.0          '5-6 hours'
# 2  7.03                   5               0.0  'Less than 5 hours'
# 3  5.59                   2               0.0          '7-8 hours'
# 4  8.13                   3               0.0          '5-6 hours'
#
#   Dietary Habits   Degree Have you ever had suicidal thoughts ?  \
# 0        Healthy  B.Pharm                                   Yes
# 1       Moderate      BSc                                    No
# 2        Healthy       BA                                    No
# 3       Moderate      BCA                                   Yes
# 4       Moderate   M.Tech                                   Yes
#
#    Work/Study Hours  Financial Stress Family History of Mental Illness  \
# 0                 3                 1                               No
# 1                 3                 2                              Yes
# 2                 9                 1                              Yes
# 3                 4                 5                              Yes
# 4                 1                 1                               No
#
#    Depression
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# ## EDA & Interactive Visualization

# %%
#Classification On The Basis Of Gender
classifi=df.groupby("Gender")["Academic Pressure"].mean().reset_index()
classifi
# Out:
#    Gender  Academic Pressure
# 0  Female           3.175842
# 1    Male           3.113920

# %%
classifi=df.groupby("Gender")["Study Satisfaction"].mean().reset_index()
classifi
# Out:
#    Gender  Study Satisfaction
# 0  Female            2.968264
# 1    Male            2.924675

# %%
classifi_stu=df.groupby(["Gender","Profession"])["Academic Pressure"].sum().reset_index()
classifi_stu.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_25573_row0_col2, #T_25573_row1_col2, #T_25573_row2_col2, #T_25573_row3_col2, #T_25573_row4_col2, #T_25573_row5_col2, #T_25573_row6_col2, #T_25573_row8_col2, #T_25573_row9_col2, #T_25573_row10_col2, #T_25573_row11_col2, #T_25573_row12_col2, #T_25573_row13_col2, #T_25573_row14_col2, #T_25573_row15_col2, #T_25573_row16_col2, #T_25573_row18_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_25573_row7_col2 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_25573_row17_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_25573">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25573_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_25573_level0_col1" class="col_heading level0 col1" >Profession</th>
#       <th id="T_25573_level0_col2" class="col_heading level0 col2" >Academic Pressure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25573_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25573_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_25573_row0_col1" class="data row0 col1" >'Content Writer'</td>
#       <td id="T_25573_row0_col2" class="data row0 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25573_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_25573_row1_col1" class="data row1 col1" >'Digital Marketer'</td>
#       <td id="T_25573_row1_col2" class="data row1 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25573_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_25573_row2_col1" class="data row2 col1" >'UX/UI Designer'</td>
#       <td id="T_25573_row2_col2" class="data row2 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25573_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_25573_row3_col1" class="data row3 col1" >Architect</td>
#       <td id="T_25573_row3_col2" class="data row3 col2" >19</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25573_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_25573_row4_col1" class="data row4 col1" >Chef</td>
#       <td id="T_25573_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25573_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_25573_row5_col1" class="data row5 col1" >Doctor</td>
#       <td id="T_25573_row5_col2" class="data row5 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_25573_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_25573_row6_col1" class="data row6 col1" >Entrepreneur</td>
#       <td id="T_25573_row6_col2" class="data row6 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_25573_row7_col0" class="data row7 col0" >Female</td>
#       <td id="T_25573_row7_col1" class="data row7 col1" >Student</td>
#       <td id="T_25573_row7_col2" class="data row7 col2" >39180</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_25573_row8_col0" class="data row8 col0" >Male</td>
#       <td id="T_25573_row8_col1" class="data row8 col1" >'Civil Engineer'</td>
#       <td id="T_25573_row8_col2" class="data row8 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_25573_row9_col0" class="data row9 col0" >Male</td>
#       <td id="T_25573_row9_col1" class="data row9 col1" >'Content Writer'</td>
#       <td id="T_25573_row9_col2" class="data row9 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_25573_row10_col0" class="data row10 col0" >Male</td>
#       <td id="T_25573_row10_col1" class="data row10 col1" >'Digital Marketer'</td>
#       <td id="T_25573_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_25573_row11_col0" class="data row11 col0" >Male</td>
#       <td id="T_25573_row11_col1" class="data row11 col1" >'Educational Consultant'</td>
#       <td id="T_25573_row11_col2" class="data row11 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_25573_row12_col0" class="data row12 col0" >Male</td>
#       <td id="T_25573_row12_col1" class="data row12 col1" >Architect</td>
#       <td id="T_25573_row12_col2" class="data row12 col2" >11</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_25573_row13_col0" class="data row13 col0" >Male</td>
#       <td id="T_25573_row13_col1" class="data row13 col1" >Doctor</td>
#       <td id="T_25573_row13_col2" class="data row13 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_25573_row14_col0" class="data row14 col0" >Male</td>
#       <td id="T_25573_row14_col1" class="data row14 col1" >Lawyer</td>
#       <td id="T_25573_row14_col2" class="data row14 col2" >4</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_25573_row15_col0" class="data row15 col0" >Male</td>
#       <td id="T_25573_row15_col1" class="data row15 col1" >Manager</td>
#       <td id="T_25573_row15_col2" class="data row15 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_25573_row16_col0" class="data row16 col0" >Male</td>
#       <td id="T_25573_row16_col1" class="data row16 col1" >Pharmacist</td>
#       <td id="T_25573_row16_col2" class="data row16 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_25573_row17_col0" class="data row17 col0" >Male</td>
#       <td id="T_25573_row17_col1" class="data row17 col1" >Student</td>
#       <td id="T_25573_row17_col2" class="data row17 col2" >48343</td>
#     </tr>
#     <tr>
#       <th id="T_25573_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_25573_row18_col0" class="data row18 col0" >Male</td>
#       <td id="T_25573_row18_col1" class="data row18 col1" >Teacher</td>
#       <td id="T_25573_row18_col2" class="data row18 col2" >21</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.scatter(
    classifi_stu,
    x="Profession",
    y="Academic Pressure",
    color="Gender",
    title="Classification Between Academic Pressure And Professions",
    color_discrete_sequence=["purple", "orange", "green"]
)

# Customizing fonts
fig.update_layout(
    title_font=dict(family="Arial Black", size=24, color="black"),
    font=dict(family="Verdana", size=15, color="black"),  # Applies to ticks, axis labels, legend
    legend_title_font=dict(family="Courier New", size=17, color="purple",weight="bold"),
    yaxis=dict(tickformat=",", title_font=dict(family="Verdana", size=16, color="black",weight="bold")),
    xaxis=dict(title_font=dict(family="Verdana", size=16, color="black",weight="bold"))
)

fig.show()

# %%
xf=df[df["Profession"]=="Student"]
xf.groupby("Profession")["Study Satisfaction"].sum().reset_index()
plt.figure(figsize=(10,6))
sns.histplot(data=xf,kde=True)
plt.title("Clasifification Counts Counts By Students",fontweight="bold")
plt.xlabel("Students",fontweight="bold")
plt.ylabel("Counts",fontweight="bold")
plt.show()

# %%
#Alternate Visualization For Better Understanding
classifi_pro=df.groupby("Profession").agg({
    "Academic Pressure":"sum",
    "Work Pressure":"sum"
})
classifi_pro
# Out:
#                           Academic Pressure  Work Pressure
# Profession
# 'Civil Engineer'                          5              0
# 'Content Writer'                         10              0
# 'Digital Marketer'                       11              0
# 'Educational Consultant'                  3              0
# 'UX/UI Designer'                          3              0
# Architect                                30              0
# Chef                                      5              0
# Doctor                                    8              0
# Entrepreneur                              3              0
# Lawyer                                    4              0
# Manager                                   3              0
# Pharmacist                                8              0
# Student                               87523             12
# Teacher                                  21              0

# %% [markdown]
# ## `Correlation Chart`

# %%
#Correlation Classification
classifi_corr=df.select_dtypes(include="number").corr()
plt.figure(figsize=(12,8))
sns.heatmap(classifi_corr,annot=True,fmt=".2f",cmap="Greens")
plt.show()

# %%
df.rename(columns={"Have you ever had suicidal thoughts ?":"Suicidal Thoughts Occured"},inplace=True)  # Renaming Column Name

# %%
suici_th=df.groupby(["Gender","Profession"])["Suicidal Thoughts Occured"].value_counts().reset_index()
suici_th.style.background_gradient(cmap="Oranges")
# Out:
# <style type="text/css">
# #T_6a04b_row0_col3, #T_6a04b_row1_col3, #T_6a04b_row2_col3, #T_6a04b_row3_col3, #T_6a04b_row4_col3, #T_6a04b_row5_col3, #T_6a04b_row6_col3, #T_6a04b_row7_col3, #T_6a04b_row8_col3, #T_6a04b_row11_col3, #T_6a04b_row12_col3, #T_6a04b_row13_col3, #T_6a04b_row14_col3, #T_6a04b_row15_col3, #T_6a04b_row16_col3, #T_6a04b_row17_col3, #T_6a04b_row18_col3, #T_6a04b_row19_col3, #T_6a04b_row20_col3, #T_6a04b_row23_col3 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_6a04b_row9_col3 {
#   background-color: #c64102;
#   color: #f1f1f1;
# }
# #T_6a04b_row10_col3 {
#   background-color: #fd984b;
#   color: #000000;
# }
# #T_6a04b_row21_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_6a04b_row22_col3 {
#   background-color: #f57622;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6a04b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a04b_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_6a04b_level0_col1" class="col_heading level0 col1" >Profession</th>
#       <th id="T_6a04b_level0_col2" class="col_heading level0 col2" >Suicidal Thoughts Occured</th>
#       <th id="T_6a04b_level0_col3" class="col_heading level0 col3" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a04b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a04b_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_6a04b_row0_col1" class="data row0 col1" >'Content Writer'</td>
#       <td id="T_6a04b_row0_col2" class="data row0 col2" >Yes</td>
#       <td id="T_6a04b_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a04b_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_6a04b_row1_col1" class="data row1 col1" >'Digital Marketer'</td>
#       <td id="T_6a04b_row1_col2" class="data row1 col2" >No</td>
#       <td id="T_6a04b_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a04b_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_6a04b_row2_col1" class="data row2 col1" >'Digital Marketer'</td>
#       <td id="T_6a04b_row2_col2" class="data row2 col2" >Yes</td>
#       <td id="T_6a04b_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a04b_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_6a04b_row3_col1" class="data row3 col1" >'UX/UI Designer'</td>
#       <td id="T_6a04b_row3_col2" class="data row3 col2" >Yes</td>
#       <td id="T_6a04b_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a04b_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_6a04b_row4_col1" class="data row4 col1" >Architect</td>
#       <td id="T_6a04b_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_6a04b_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a04b_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_6a04b_row5_col1" class="data row5 col1" >Architect</td>
#       <td id="T_6a04b_row5_col2" class="data row5 col2" >No</td>
#       <td id="T_6a04b_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a04b_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_6a04b_row6_col1" class="data row6 col1" >Chef</td>
#       <td id="T_6a04b_row6_col2" class="data row6 col2" >Yes</td>
#       <td id="T_6a04b_row6_col3" class="data row6 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a04b_row7_col0" class="data row7 col0" >Female</td>
#       <td id="T_6a04b_row7_col1" class="data row7 col1" >Doctor</td>
#       <td id="T_6a04b_row7_col2" class="data row7 col2" >No</td>
#       <td id="T_6a04b_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a04b_row8_col0" class="data row8 col0" >Female</td>
#       <td id="T_6a04b_row8_col1" class="data row8 col1" >Entrepreneur</td>
#       <td id="T_6a04b_row8_col2" class="data row8 col2" >Yes</td>
#       <td id="T_6a04b_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a04b_row9_col0" class="data row9 col0" >Female</td>
#       <td id="T_6a04b_row9_col1" class="data row9 col1" >Student</td>
#       <td id="T_6a04b_row9_col2" class="data row9 col2" >Yes</td>
#       <td id="T_6a04b_row9_col3" class="data row9 col3" >7816</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6a04b_row10_col0" class="data row10 col0" >Female</td>
#       <td id="T_6a04b_row10_col1" class="data row10 col1" >Student</td>
#       <td id="T_6a04b_row10_col2" class="data row10 col2" >No</td>
#       <td id="T_6a04b_row10_col3" class="data row10 col3" >4523</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6a04b_row11_col0" class="data row11 col0" >Male</td>
#       <td id="T_6a04b_row11_col1" class="data row11 col1" >'Civil Engineer'</td>
#       <td id="T_6a04b_row11_col2" class="data row11 col2" >Yes</td>
#       <td id="T_6a04b_row11_col3" class="data row11 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6a04b_row12_col0" class="data row12 col0" >Male</td>
#       <td id="T_6a04b_row12_col1" class="data row12 col1" >'Content Writer'</td>
#       <td id="T_6a04b_row12_col2" class="data row12 col2" >Yes</td>
#       <td id="T_6a04b_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6a04b_row13_col0" class="data row13 col0" >Male</td>
#       <td id="T_6a04b_row13_col1" class="data row13 col1" >'Digital Marketer'</td>
#       <td id="T_6a04b_row13_col2" class="data row13 col2" >Yes</td>
#       <td id="T_6a04b_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6a04b_row14_col0" class="data row14 col0" >Male</td>
#       <td id="T_6a04b_row14_col1" class="data row14 col1" >'Educational Consultant'</td>
#       <td id="T_6a04b_row14_col2" class="data row14 col2" >Yes</td>
#       <td id="T_6a04b_row14_col3" class="data row14 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6a04b_row15_col0" class="data row15 col0" >Male</td>
#       <td id="T_6a04b_row15_col1" class="data row15 col1" >Architect</td>
#       <td id="T_6a04b_row15_col2" class="data row15 col2" >No</td>
#       <td id="T_6a04b_row15_col3" class="data row15 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6a04b_row16_col0" class="data row16 col0" >Male</td>
#       <td id="T_6a04b_row16_col1" class="data row16 col1" >Architect</td>
#       <td id="T_6a04b_row16_col2" class="data row16 col2" >Yes</td>
#       <td id="T_6a04b_row16_col3" class="data row16 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6a04b_row17_col0" class="data row17 col0" >Male</td>
#       <td id="T_6a04b_row17_col1" class="data row17 col1" >Doctor</td>
#       <td id="T_6a04b_row17_col2" class="data row17 col2" >Yes</td>
#       <td id="T_6a04b_row17_col3" class="data row17 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6a04b_level0_row18" class="row_heading

# %% [markdown]
# ### `Suicidal Thoughts Occured Based On Professions`

# %%
plt.figure(figsize=(15,10))
sns.catplot(data=suici_th,x="Profession",y="count",hue="Suicidal Thoughts Occured",palette="Set1")
plt.xticks(rotation=90)
plt.xlabel("Professions",fontweight="bold",fontsize=12)
plt.ylabel("Counts",fontweight="bold",fontsize=12)
plt.title("Suicidal Thoughts Occured Based On Professions",fontweight="bold",fontsize=12)
plt.show()

# %% [markdown]
# ### `Alternate visualization For Better Understanding`

# %% [markdown]
# `Suicidal Thoughts by Profession, Gender, and Response`

# %%
# Set plot size and style
sns.set(style="whitegrid")
plt.figure(figsize=(16, 10))

# Create a FacetGrid to separate plots by suicidal thoughts response (Yes/No)
g = sns.catplot(
    data=suici_th,
    kind="bar",
    x="Profession",
    y="count",
    hue="Gender",
    col="Suicidal Thoughts Occured",
    palette="magma",
    height=6,
    aspect=1.5
)

# Adjust labels
g.set_xticklabels(rotation=45, ha='right')
g.set_axis_labels("Profession", "Count",)
g.set_titles("Response: {col_name}",fontweight="bold",fontsize=20)
plt.subplots_adjust(top=0.85)
g.fig.suptitle("Suicidal Thoughts by Profession, Gender, and Response",fontweight="bold",fontsize=16)

plt.show()

# %% [markdown]
# ### `Family History Of Mental Illness By Gender And Profession`

# %%
family_his=df.groupby(["Gender","Profession"])["Family History of Mental Illness"].value_counts().reset_index()
family_his.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_002d3_row0_col3, #T_002d3_row1_col3, #T_002d3_row2_col3, #T_002d3_row3_col3, #T_002d3_row4_col3, #T_002d3_row5_col3, #T_002d3_row6_col3, #T_002d3_row7_col3, #T_002d3_row8_col3, #T_002d3_row9_col3, #T_002d3_row12_col3, #T_002d3_row13_col3, #T_002d3_row14_col3, #T_002d3_row15_col3, #T_002d3_row16_col3, #T_002d3_row17_col3, #T_002d3_row18_col3, #T_002d3_row19_col3, #T_002d3_row20_col3, #T_002d3_row21_col3, #T_002d3_row24_col3, #T_002d3_row25_col3 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_002d3_row10_col3 {
#   background-color: #c4161c;
#   color: #f1f1f1;
# }
# #T_002d3_row11_col3 {
#   background-color: #cb181d;
#   color: #f1f1f1;
# }
# #T_002d3_row22_col3 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_002d3_row23_col3 {
#   background-color: #920a13;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_002d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_002d3_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_002d3_level0_col1" class="col_heading level0 col1" >Profession</th>
#       <th id="T_002d3_level0_col2" class="col_heading level0 col2" >Family History of Mental Illness</th>
#       <th id="T_002d3_level0_col3" class="col_heading level0 col3" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_002d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_002d3_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_002d3_row0_col1" class="data row0 col1" >'Content Writer'</td>
#       <td id="T_002d3_row0_col2" class="data row0 col2" >No</td>
#       <td id="T_002d3_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_002d3_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_002d3_row1_col1" class="data row1 col1" >'Digital Marketer'</td>
#       <td id="T_002d3_row1_col2" class="data row1 col2" >No</td>
#       <td id="T_002d3_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_002d3_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_002d3_row2_col1" class="data row2 col1" >'Digital Marketer'</td>
#       <td id="T_002d3_row2_col2" class="data row2 col2" >Yes</td>
#       <td id="T_002d3_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_002d3_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_002d3_row3_col1" class="data row3 col1" >'UX/UI Designer'</td>
#       <td id="T_002d3_row3_col2" class="data row3 col2" >No</td>
#       <td id="T_002d3_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_002d3_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_002d3_row4_col1" class="data row4 col1" >Architect</td>
#       <td id="T_002d3_row4_col2" class="data row4 col2" >Yes</td>
#       <td id="T_002d3_row4_col3" class="data row4 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_002d3_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_002d3_row5_col1" class="data row5 col1" >Architect</td>
#       <td id="T_002d3_row5_col2" class="data row5 col2" >No</td>
#       <td id="T_002d3_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_002d3_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_002d3_row6_col1" class="data row6 col1" >Chef</td>
#       <td id="T_002d3_row6_col2" class="data row6 col2" >No</td>
#       <td id="T_002d3_row6_col3" class="data row6 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_002d3_row7_col0" class="data row7 col0" >Female</td>
#       <td id="T_002d3_row7_col1" class="data row7 col1" >Chef</td>
#       <td id="T_002d3_row7_col2" class="data row7 col2" >Yes</td>
#       <td id="T_002d3_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_002d3_row8_col0" class="data row8 col0" >Female</td>
#       <td id="T_002d3_row8_col1" class="data row8 col1" >Doctor</td>
#       <td id="T_002d3_row8_col2" class="data row8 col2" >No</td>
#       <td id="T_002d3_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_002d3_row9_col0" class="data row9 col0" >Female</td>
#       <td id="T_002d3_row9_col1" class="data row9 col1" >Entrepreneur</td>
#       <td id="T_002d3_row9_col2" class="data row9 col2" >No</td>
#       <td id="T_002d3_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_002d3_row10_col0" class="data row10 col0" >Female</td>
#       <td id="T_002d3_row10_col1" class="data row10 col1" >Student</td>
#       <td id="T_002d3_row10_col2" class="data row10 col2" >No</td>
#       <td id="T_002d3_row10_col3" class="data row10 col3" >6258</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_002d3_row11_col0" class="data row11 col0" >Female</td>
#       <td id="T_002d3_row11_col1" class="data row11 col1" >Student</td>
#       <td id="T_002d3_row11_col2" class="data row11 col2" >Yes</td>
#       <td id="T_002d3_row11_col3" class="data row11 col3" >6081</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_002d3_row12_col0" class="data row12 col0" >Male</td>
#       <td id="T_002d3_row12_col1" class="data row12 col1" >'Civil Engineer'</td>
#       <td id="T_002d3_row12_col2" class="data row12 col2" >Yes</td>
#       <td id="T_002d3_row12_col3" class="data row12 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_002d3_row13_col0" class="data row13 col0" >Male</td>
#       <td id="T_002d3_row13_col1" class="data row13 col1" >'Content Writer'</td>
#       <td id="T_002d3_row13_col2" class="data row13 col2" >Yes</td>
#       <td id="T_002d3_row13_col3" class="data row13 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_002d3_row14_col0" class="data row14 col0" >Male</td>
#       <td id="T_002d3_row14_col1" class="data row14 col1" >'Digital Marketer'</td>
#       <td id="T_002d3_row14_col2" class="data row14 col2" >Yes</td>
#       <td id="T_002d3_row14_col3" class="data row14 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_002d3_row15_col0" class="data row15 col0" >Male</td>
#       <td id="T_002d3_row15_col1" class="data row15 col1" >'Educational Consultant'</td>
#       <td id="T_002d3_row15_col2" class="data row15 col2" >Yes</td>
#       <td id="T_002d3_row15_col3" class="data row15 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_002d3_row16_col0" class="data row16 col0" >Male</td>
#       <td id="T_002d3_row16_col1" class="data row16 col1" >Architect</td>
#       <td id="T_002d3_row16_col2" class="data row16 col2" >Yes</td>
#       <td id="T_002d3_row16_col3" class="data row16 col3" >3</td>
#     </tr>
#     <tr>
#       <th id="T_002d3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_002d3_row17_col0" class="data row17 col0" >Male</td>
#       <td id="T_002d3_row17_col1" class="data row17 col1" >Doctor</td>
#       <td id="T_002d3_row17_col2" class="data row17 col2" >No</td>
#       <td id="T_002d3_row17_col3" class="data row17 col3" >1</td>
#     </tr>
#     <tr>
#       <th id

# %%
plt.figure(figsize=(12,6))
g=sns.catplot(
    data=family_his,
    x="Profession",
    y="count",
    hue="Gender",
    col="Family History of Mental Illness",
    palette="Set1",
    height=6,
    aspect=1.5
)

g.set_xticklabels(rotation=90)
g.set_axis_labels("Professions","Count",fontweight="bold",fontsize=13)
g.fig.suptitle("Family History Of Mental Illness By Profession And Gender",fontweight="bold",fontsize=20)
plt.subplots_adjust(top=0.85)
g.set_titles("Response: {col_name}",fontweight="bold",fontsize=20)
plt.show()

# %% [markdown]
# ### `Alternate Visualization`
# #### Mental Illness Link By Family History And Profession

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=family_his, x="Profession", hue="Family History of Mental Illness", palette="magma")
plt.xticks(rotation=45)
plt.title("Mental Illness Link By Family History And Profession",fontweight="bold",fontsize=18)
plt.xlabel("Professions",fontweight="bold",fontsize=13)
plt.ylabel("Counts",fontweight="bold",fontsize=13)
plt.show()

# %%
df=df[df["Sleep Duration"]!="Others"] # Removing Others From Column Sleep Duration

# %%
sleep_qua=df.groupby("Gender")["Sleep Duration"].value_counts().reset_index()
sleep_qua.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_34528_row0_col2 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_34528_row1_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_34528_row2_col2 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_34528_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_34528_row4_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_34528_row5_col2 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_34528_row6_col2 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_34528_row7_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# </style>
# <table id="T_34528">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34528_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_34528_level0_col1" class="col_heading level0 col1" >Sleep Duration</th>
#       <th id="T_34528_level0_col2" class="col_heading level0 col2" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34528_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34528_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_34528_row0_col1" class="data row0 col1" >'Less than 5 hours'</td>
#       <td id="T_34528_row0_col2" class="data row0 col2" >3628</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34528_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_34528_row1_col1" class="data row1 col1" >'7-8 hours'</td>
#       <td id="T_34528_row1_col2" class="data row1 col2" >3291</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34528_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_34528_row2_col1" class="data row2 col1" >'5-6 hours'</td>
#       <td id="T_34528_row2_col2" class="data row2 col2" >2787</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34528_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_34528_row3_col1" class="data row3 col1" >'More than 8 hours'</td>
#       <td id="T_34528_row3_col2" class="data row3 col2" >2637</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34528_row4_col0" class="data row4 col0" >Male</td>
#       <td id="T_34528_row4_col1" class="data row4 col1" >'Less than 5 hours'</td>
#       <td id="T_34528_row4_col2" class="data row4 col2" >4681</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34528_row5_col0" class="data row5 col0" >Male</td>
#       <td id="T_34528_row5_col1" class="data row5 col1" >'7-8 hours'</td>
#       <td id="T_34528_row5_col2" class="data row5 col2" >4055</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34528_row6_col0" class="data row6 col0" >Male</td>
#       <td id="T_34528_row6_col1" class="data row6 col1" >'More than 8 hours'</td>
#       <td id="T_34528_row6_col2" class="data row6 col2" >3407</td>
#     </tr>
#     <tr>
#       <th id="T_34528_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34528_row7_col0" class="data row7 col0" >Male</td>
#       <td id="T_34528_row7_col1" class="data row7 col1" >'5-6 hours'</td>
#       <td id="T_34528_row7_col2" class="data row7 col2" >3394</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(15,6))
sns.barplot(data=sleep_qua,x="Sleep Duration",y="count",hue="Gender",palette="Paired")
plt.title("Sleep Quality By Gender",fontweight="bold",fontsize=18)
plt.xlabel("Sleep Duration",fontweight="bold",fontsize=13)
plt.ylabel("Count",fontweight="bold",fontsize=13)
plt.show()

# %% [markdown]
# ### ` Visualization Of Diatary Habits By Gender And Profession`

# %%
Dietary_Habits=df.groupby(["Gender","Profession","Dietary Habits"]).size().reset_index(name="Counts")
Dietary_Habits.style.background_gradient(cmap="Purples")
# Out:
# <style type="text/css">
# #T_33094_row0_col3, #T_33094_row1_col3, #T_33094_row2_col3, #T_33094_row3_col3, #T_33094_row4_col3, #T_33094_row5_col3, #T_33094_row6_col3, #T_33094_row7_col3, #T_33094_row8_col3, #T_33094_row9_col3, #T_33094_row10_col3, #T_33094_row13_col3, #T_33094_row15_col3, #T_33094_row16_col3, #T_33094_row17_col3, #T_33094_row18_col3, #T_33094_row19_col3, #T_33094_row20_col3, #T_33094_row21_col3, #T_33094_row22_col3, #T_33094_row23_col3, #T_33094_row24_col3, #T_33094_row25_col3, #T_33094_row26_col3, #T_33094_row29_col3, #T_33094_row31_col3, #T_33094_row32_col3, #T_33094_row33_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_33094_row11_col3 {
#   background-color: #8986be;
#   color: #f1f1f1;
# }
# #T_33094_row12_col3 {
#   background-color: #6c54a5;
#   color: #f1f1f1;
# }
# #T_33094_row14_col3 {
#   background-color: #786db2;
#   color: #f1f1f1;
# }
# #T_33094_row27_col3 {
#   background-color: #7b74b5;
#   color: #f1f1f1;
# }
# #T_33094_row28_col3 {
#   background-color: #552a90;
#   color: #f1f1f1;
# }
# #T_33094_row30_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_33094">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33094_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_33094_level0_col1" class="col_heading level0 col1" >Profession</th>
#       <th id="T_33094_level0_col2" class="col_heading level0 col2" >Dietary Habits</th>
#       <th id="T_33094_level0_col3" class="col_heading level0 col3" >Counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33094_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33094_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_33094_row0_col1" class="data row0 col1" >'Content Writer'</td>
#       <td id="T_33094_row0_col2" class="data row0 col2" >Moderate</td>
#       <td id="T_33094_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33094_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_33094_row1_col1" class="data row1 col1" >'Digital Marketer'</td>
#       <td id="T_33094_row1_col2" class="data row1 col2" >Healthy</td>
#       <td id="T_33094_row1_col3" class="data row1 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33094_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_33094_row2_col1" class="data row2 col1" >'Digital Marketer'</td>
#       <td id="T_33094_row2_col2" class="data row2 col2" >Moderate</td>
#       <td id="T_33094_row2_col3" class="data row2 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_33094_row3_col0" class="data row3 col0" >Female</td>
#       <td id="T_33094_row3_col1" class="data row3 col1" >'UX/UI Designer'</td>
#       <td id="T_33094_row3_col2" class="data row3 col2" >Moderate</td>
#       <td id="T_33094_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_33094_row4_col0" class="data row4 col0" >Female</td>
#       <td id="T_33094_row4_col1" class="data row4 col1" >Architect</td>
#       <td id="T_33094_row4_col2" class="data row4 col2" >Healthy</td>
#       <td id="T_33094_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_33094_row5_col0" class="data row5 col0" >Female</td>
#       <td id="T_33094_row5_col1" class="data row5 col1" >Architect</td>
#       <td id="T_33094_row5_col2" class="data row5 col2" >Moderate</td>
#       <td id="T_33094_row5_col3" class="data row5 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_33094_row6_col0" class="data row6 col0" >Female</td>
#       <td id="T_33094_row6_col1" class="data row6 col1" >Architect</td>
#       <td id="T_33094_row6_col2" class="data row6 col2" >Unhealthy</td>
#       <td id="T_33094_row6_col3" class="data row6 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_33094_row7_col0" class="data row7 col0" >Female</td>
#       <td id="T_33094_row7_col1" class="data row7 col1" >Chef</td>
#       <td id="T_33094_row7_col2" class="data row7 col2" >Healthy</td>
#       <td id="T_33094_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_33094_row8_col0" class="data row8 col0" >Female</td>
#       <td id="T_33094_row8_col1" class="data row8 col1" >Chef</td>
#       <td id="T_33094_row8_col2" class="data row8 col2" >Moderate</td>
#       <td id="T_33094_row8_col3" class="data row8 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_33094_row9_col0" class="data row9 col0" >Female</td>
#       <td id="T_33094_row9_col1" class="data row9 col1" >Doctor</td>
#       <td id="T_33094_row9_col2" class="data row9 col2" >Healthy</td>
#       <td id="T_33094_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_33094_row10_col0" class="data row10 col0" >Female</td>
#       <td id="T_33094_row10_col1" class="data row10 col1" >Entrepreneur</td>
#       <td id="T_33094_row10_col2" class="data row10 col2" >Moderate</td>
#       <td id="T_33094_row10_col3" class="data row10 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_33094_row11_col0" class="data row11 col0" >Female</td>
#       <td id="T_33094_row11_col1" class="data row11 col1" >Student</td>
#       <td id="T_33094_row11_col2" class="data row11 col2" >Healthy</td>
#       <td id="T_33094_row11_col3" class="data row11 col3" >3616</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_33094_row12_col0" class="data row12 col0" >Female</td>
#       <td id="T_33094_row12_col1" class="data row12 col1" >Student</td>
#       <td id="T_33094_row12_col2" class="data row12 col2" >Moderate</td>
#       <td id="T_33094_row12_col3" class="data row12 col3" >4571</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_33094_row13_col0" class="data row13 col0" >Female</td>
#       <td id="T_33094_row13_col1" class="data row13 col1" >Student</td>
#       <td id="T_33094_row13_col2" class="data row13 col2" >Others</td>
#       <td id="T_33094_row13_col3" class="data row13 col3" >4</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_33094_row14_col0" class="data row14 col0" >Female</td>
#       <td id="T_33094_row14_col1" class="data row14 col1" >Student</td>
#       <td id="T_33094_row14_col2" class="data row14 col2" >Unhealthy</td>
#       <td id="T_33094_row14_col3" class="data row14 col3" >4139</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_33094_row15_col0" class="data row15 col0" >Male</td>
#       <td id="T_33094_row15_col1" class="data row15 col1" >'Civil Engineer'</td>
#       <td id="T_33094_row15_col2" class="data row15 col2" >Healthy</td>
#       <td id="T_33094_row15_col3" class="data row15 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_33094_row16_col0" class="data row16 col0" >Male</td>
#       <td id="T_33094_row16_col1" class="data row16 col1" >'Content Writer'</td>
#       <td id="T_33094_row16_col2" class="data row16 col2" >Moderate</td>
#       <td id="T_33094_row16_col3" class="data row16 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33094_level0_row17" class="row_heading level0 r

# %%
Dietary_Habits["Grouped"]= Dietary_Habits["Gender"]+"|"+Dietary_Habits["Dietary Habits"]
plt.figure(figsize=(15,8))
sns.barplot(data=Dietary_Habits,x="Profession",y='Counts',hue="Grouped",palette="Paired")
plt.xticks(rotation=45)
plt.xlabel("Professions",fontweight="bold",fontsize=13)
plt.ylabel("Counts",fontweight="bold",fontsize=13)
plt.title("Diatary Habits By Gender And Profession",fontweight="bold",fontsize=18)
plt.show()

# %% [markdown]
# ### `Which City Is The Most Affected By Depression Counts`

# %%
city_diff=df.groupby(["Gender","City","Profession"]).size().reset_index(name="Counts")
city_diff
plt.figure(figsize=(15,8))
sns.barplot(data=city_diff,x="Profession",y='City',hue="Gender",palette="magma")
plt.xticks(rotation=55,fontweight="bold")
plt.xlabel("Professions",fontweight="bold",fontsize=13)
plt.ylabel("Counts",fontweight="bold",fontsize=13)
plt.title("The Most Affected City By Depression Counts",fontweight="bold",fontsize=18)
plt.show()

# %% [markdown]
# ### `Relation Link Between Various Factors And Depression`

# %%
rela_li=df.groupby(["Gender","Profession"]).agg({
    "Age":"mean",
    "Academic Pressure":"sum",
    "Work Pressure":"sum",
    "CGPA":"sum",
    "Study Satisfaction":"sum",
    "Job Satisfaction":"sum",
    "Work/Study Hours":"sum",
    "Financial Stress":"sum",
    "Depression":"sum"
}).reset_index()

rela_li.style.background_gradient(cmap="Reds")
# Out:
# <style type="text/css">
# #T_9b165_row0_col2, #T_9b165_row17_col3, #T_9b165_row17_col4, #T_9b165_row17_col5, #T_9b165_row17_col6, #T_9b165_row17_col7, #T_9b165_row17_col8, #T_9b165_row17_col9, #T_9b165_row17_col10 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_9b165_row0_col3, #T_9b165_row0_col4, #T_9b165_row0_col5, #T_9b165_row0_col6, #T_9b165_row0_col7, #T_9b165_row0_col8, #T_9b165_row0_col9, #T_9b165_row0_col10, #T_9b165_row1_col3, #T_9b165_row1_col4, #T_9b165_row1_col5, #T_9b165_row1_col6, #T_9b165_row1_col7, #T_9b165_row1_col8, #T_9b165_row1_col9, #T_9b165_row1_col10, #T_9b165_row2_col3, #T_9b165_row2_col4, #T_9b165_row2_col5, #T_9b165_row2_col6, #T_9b165_row2_col7, #T_9b165_row2_col8, #T_9b165_row2_col9, #T_9b165_row2_col10, #T_9b165_row3_col3, #T_9b165_row3_col4, #T_9b165_row3_col5, #T_9b165_row3_col6, #T_9b165_row3_col7, #T_9b165_row3_col8, #T_9b165_row3_col9, #T_9b165_row3_col10, #T_9b165_row4_col3, #T_9b165_row4_col4, #T_9b165_row4_col5, #T_9b165_row4_col6, #T_9b165_row4_col7, #T_9b165_row4_col8, #T_9b165_row4_col9, #T_9b165_row4_col10, #T_9b165_row5_col3, #T_9b165_row5_col4, #T_9b165_row5_col5, #T_9b165_row5_col6, #T_9b165_row5_col7, #T_9b165_row5_col8, #T_9b165_row5_col9, #T_9b165_row5_col10, #T_9b165_row6_col2, #T_9b165_row6_col3, #T_9b165_row6_col4, #T_9b165_row6_col5, #T_9b165_row6_col6, #T_9b165_row6_col7, #T_9b165_row6_col8, #T_9b165_row6_col9, #T_9b165_row6_col10, #T_9b165_row7_col4, #T_9b165_row8_col2, #T_9b165_row8_col3, #T_9b165_row8_col4, #T_9b165_row8_col5, #T_9b165_row8_col6, #T_9b165_row8_col7, #T_9b165_row8_col8, #T_9b165_row8_col9, #T_9b165_row8_col10, #T_9b165_row9_col3, #T_9b165_row9_col4, #T_9b165_row9_col5, #T_9b165_row9_col6, #T_9b165_row9_col7, #T_9b165_row9_col8, #T_9b165_row9_col9, #T_9b165_row9_col10, #T_9b165_row10_col3, #T_9b165_row10_col4, #T_9b165_row10_col5, #T_9b165_row10_col6, #T_9b165_row10_col7, #T_9b165_row10_col8, #T_9b165_row10_col9, #T_9b165_row10_col10, #T_9b165_row11_col3, #T_9b165_row11_col4, #T_9b165_row11_col5, #T_9b165_row11_col6, #T_9b165_row11_col7, #T_9b165_row11_col8, #T_9b165_row11_col9, #T_9b165_row11_col10, #T_9b165_row12_col3, #T_9b165_row12_col4, #T_9b165_row12_col5, #T_9b165_row12_col6, #T_9b165_row12_col7, #T_9b165_row12_col8, #T_9b165_row12_col9, #T_9b165_row12_col10, #T_9b165_row13_col3, #T_9b165_row13_col4, #T_9b165_row13_col5, #T_9b165_row13_col6, #T_9b165_row13_col7, #T_9b165_row13_col8, #T_9b165_row13_col9, #T_9b165_row13_col10, #T_9b165_row14_col3, #T_9b165_row14_col4, #T_9b165_row14_col5, #T_9b165_row14_col6, #T_9b165_row14_col7, #T_9b165_row14_col8, #T_9b165_row14_col9, #T_9b165_row14_col10, #T_9b165_row15_col3, #T_9b165_row15_col4, #T_9b165_row15_col5, #T_9b165_row15_col6, #T_9b165_row15_col7, #T_9b165_row15_col8, #T_9b165_row15_col9, #T_9b165_row15_col10, #T_9b165_row16_col3, #T_9b165_row16_col4, #T_9b165_row16_col5, #T_9b165_row16_col6, #T_9b165_row16_col7, #T_9b165_row16_col8, #T_9b165_row16_col9, #T_9b165_row16_col10, #T_9b165_row18_col3, #T_9b165_row18_col4, #T_9b165_row18_col5, #T_9b165_row18_col6, #T_9b165_row18_col7, #T_9b165_row18_col8, #T_9b165_row18_col9, #T_9b165_row18_col10 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_9b165_row1_col2, #T_9b165_row7_col7 {
#   background-color: #fcb69b;
#   color: #000000;
# }
# #T_9b165_row2_col2, #T_9b165_row11_col2, #T_9b165_row13_col2 {
#   background-color: #ad1117;
#   color: #f1f1f1;
# }
# #T_9b165_row3_col2, #T_9b165_row4_col2 {
#   background-color: #fc8f6f;
#   color: #000000;
# }
# #T_9b165_row5_col2 {
#   background-color: #f03f2e;
#   color: #f1f1f1;
# }
# #T_9b165_row7_col2 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_9b165_row7_col3 {
#   background-color: #b81419;
#   color: #f1f1f1;
# }
# #T_9b165_row7_col5, #T_9b165_row7_col8 {
#   background-color: #c1161b;
#   color: #f1f1f1;
# }
# #T_9b165_row7_col6 {
#   background-color: #b91419;
#   color: #f1f1f1;
# }
# #T_9b165_row7_col9 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_9b165_row7_col10 {
#   background-color: #be151a;
#   color: #f1f1f1;
# }
# #T_9b165_row9_col2 {
#   background-color: #fca98c;
#   color: #000000;
# }
# #T_9b165_row10_col2 {
#   background-color: #f75c41;
#   color: #f1f1f1;
# }
# #T_9b165_row12_col2 {
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_9b165_row14_col2, #T_9b165_row15_col2 {
#   background-color: #fed8c7;
#   color: #000000;
# }
# #T_9b165_row16_col2 {
#   background-color: #d01d1f;
#   color: #f1f1f1;
# }
# #T_9b165_row17_col2 {
#   background-color: #fc9373;
#   color: #000000;
# }
# #T_9b165_row18_col2 {
#   background-color: #fc8666;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9b165">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b165_level0_col0" class="col_heading level0 col0" >Gender</th>
#       <th id="T_9b165_level0_col1" class="col_heading level0 col1" >Profession</th>
#       <th id="T_9b165_level0_col2" class="col_heading level0 col2" >Age</th>
#       <th id="T_9b165_level0_col3" class="col_heading level0 col3" >Academic Pressure</th>
#       <th id="T_9b165_level0_col4" class="col_heading level0 col4" >Work Pressure</th>
#       <th id="T_9b165_level0_col5" class="col_heading level0 col5" >CGPA</th>
#       <th id="T_9b165_level0_col6" class="col_heading level0 col6" >Study Satisfaction</th>
#       <th id="T_9b165_level0_col7" class="col_heading level0 col7" >Job Satisfaction</th>
#       <th id="T_9b165_level0_col8" class="col_heading level0 col8" >Work/Study Hours</th>
#       <th id="T_9b165_level0_col9" class="col_heading level0 col9" >Financial Stress</th>
#       <th id="T_9b165_level0_col10" class="col_heading level0 col10" >Depression</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b165_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b165_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_9b165_row0_col1" class="data row0 col1" >'Content Writer'</td>
#       <td id="T_9b165_row0_col2" class="data row0 col2" >34.000000</td>
#       <td id="T_9b165_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_9b165_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9b165_row0_col5" class="data row0 col5" >6.830000</td>
#       <td id="T_9b165_row0_col6" class="data row0 col6" >4</td>
#       <td id="T_9b165_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_9b165_row0_col8" class="data row0 col8" >5</td>
#       <td id="T_9b165_row0_col9" class="data row0 col9" >5</td>
#       <td id="T_9b165_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b165_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b165_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_9b165_row1_col1" class="data row1 col1" >'Digital Marketer'</td>
#       <td id="T_9b165_row1_col2" class="data row1 col2" >24.500000</td>
#       <td id="T_9b165_row1_col3" class="data row1 col3" >10</td>
#       <td id="T_9b165_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_9b165_row1_col5" class="data row1 col5" >16.630000</td>
#       <td id="T_9b165_row1_col6" class="data row1 col6" >7</td>
#       <td id="T_9b165_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_9b165_row1_col8" class="data row1 col8" >20</td>
#       <td id="T_9b165_row1_col9" class="data row1 col9" >10</td>
#       <td id="T_9b165_row1_col10" class="data row1 col10" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9b165_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b165_row2_col0" class="data row2 col0" >Female</td>
#       <td id="T_9b165_row2_col1" class="data row2 col1" >'UX/UI Designer'</td>
#       <td id="T_9b165_row2_col2" class="data row2 col2" >32.000000</td>
#       <td id="T_9b165_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_9b165_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_9b165_row2_col5" class="data row2 col5" >9.600000</td>
#       <td id="T_9b165_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_9b165_row2_col7" class="data row2 col7" >0.000000</td>
#       <td id="T_9b165_row2_col8" class="data row2 col8" >5</td>
#       <td id="T_9b165_row2_col9" class="data
